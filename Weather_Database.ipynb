# %%
# Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime
import os

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
city_url = url + "&q=" + city.replace(" ","+")

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | srandakan
# Processing Record 2 of Set 1 | palizada
# Processing Record 3 of Set 1 | miranda
# Processing Record 4 of Set 1 | verkhoyansk
# Processing Record 5 of Set 1 | bose
# Processing Record 6 of Set 1 | avera
# Processing Record 7 of Set 1 | aksha
# Processing Record 8 of Set 1 | bathsheba
# Processing Record 9 of Set 1 | akdepe
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | cockburn town
# Processing Record 12 of Set 1 | la palma
# Processing Record 13 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 1 | talnakh
# Processing Record 15 of Set 1 | kaeng khlo
# City not found. Skipping...
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | swellendam
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | lasa
# Processing Record 21 of Set 1 | bengkulu
# Processing Record 22 of Set 1 | mahebourg
# Processing Record 23 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 1 | manaus
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | picos
# Processing Record 30 of Set 1 | alta floresta
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | geraldton
# Processing Record 33 of Set 1 | port hedland
# Processing Record 34 of Set 1 | cabo san lucas
# Processing Record 35 of Set 1 | upernavik
# Processing Record 36 of Set 1 | zhigansk
# Processing Record 37 of Set 1 | ribeira grande
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | kampene
# Processing Record 40 of Set 1 | verkh-usugli
# Processing Record 41 of Set 1 | cidreira
# Processing Record 42 of Set 1 | acapulco
# Processing Record 43 of Set 1 | husavik
# Processing Record 44 of Set 1 | rocha
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 47 of Set 1 | daitari
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | hamilton
# Processing Record 50 of Set 1 | margate
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | half moon bay
# Processing Record 3 of Set 2 | tha bo
# Processing Record 4 of Set 2 | talesh
# City not found. Skipping...
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | airai
# Processing Record 7 of Set 2 | kaitangata
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | nome
# Processing Record 10 of Set 2 | karratha
# Processing Record 11 of Set 2 | mataura
# Processing Record 12 of Set 2 | katsuura
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | vaini
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 2 | pevek
# Processing Record 18 of Set 2 | te anau
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | zhangjiakou
# Processing Record 21 of Set 2 | sao filipe
# Processing Record 22 of Set 2 | tuktoyaktuk
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | karasjok
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | catuday
# Processing Record 27 of Set 2 | guerrero negro
# Processing Record 28 of Set 2 | burnie
# Processing Record 29 of Set 2 | prieska
# Processing Record 30 of Set 2 | turukhansk
# Processing Record 31 of Set 2 | san policarpo
# Processing Record 32 of Set 2 | hasaki
# Processing Record 33 of Set 2 | lesozavodsk
# Processing Record 34 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 2 | arman
# Processing Record 36 of Set 2 | njombe
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | olinda
# Processing Record 39 of Set 2 | thompson
# Processing Record 40 of Set 2 | cape town
# Processing Record 41 of Set 2 | broome
# Processing Record 42 of Set 2 | manyana
# Processing Record 43 of Set 2 | lugovoy
# Processing Record 44 of Set 2 | beatrice
# Processing Record 45 of Set 2 | qaanaaq
# Processing Record 46 of Set 2 | anchorage
# Processing Record 47 of Set 2 | isangel
# Processing Record 48 of Set 2 | mulege
# Processing Record 49 of Set 2 | kulhudhuffushi
# Processing Record 50 of Set 2 | port elizabeth
# Processing Record 1 of Set 3 | pirsagi
# City not found. Skipping...
# Processing Record 2 of Set 3 | ostrovnoy
# Processing Record 3 of Set 3 | port lincoln
# Processing Record 4 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 3 | xuddur
# Processing Record 6 of Set 3 | nsunga
# Processing Record 7 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 3 | nikolskoye
# Processing Record 9 of Set 3 | kenora
# Processing Record 10 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 3 | sabang
# Processing Record 12 of Set 3 | eyl
# Processing Record 13 of Set 3 | khatanga
# Processing Record 14 of Set 3 | chimbote
# Processing Record 15 of Set 3 | caracuaro
# Processing Record 16 of Set 3 | saskylakh
# Processing Record 17 of Set 3 | ibra
# Processing Record 18 of Set 3 | bekovo
# Processing Record 19 of Set 3 | birjand
# Processing Record 20 of Set 3 | richards bay
# Processing Record 21 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 3 | havre-saint-pierre
# Processing Record 23 of Set 3 | hukuntsi
# Processing Record 24 of Set 3 | bubaque
# Processing Record 25 of Set 3 | boende
# Processing Record 26 of Set 3 | sorong
# Processing Record 27 of Set 3 | shamkhal
# Processing Record 28 of Set 3 | kudat
# Processing Record 29 of Set 3 | mar del plata
# Processing Record 30 of Set 3 | bambous virieux
# Processing Record 31 of Set 3 | kuytun
# Processing Record 32 of Set 3 | samarai
# Processing Record 33 of Set 3 | kholm
# Processing Record 34 of Set 3 | nenjiang
# Processing Record 35 of Set 3 | calderitas
# Processing Record 36 of Set 3 | whitehorse
# Processing Record 37 of Set 3 | tupik
# Processing Record 38 of Set 3 | esperance
# Processing Record 39 of Set 3 | bandarbeyla
# Processing Record 40 of Set 3 | dikson
# Processing Record 41 of Set 3 | narsaq
# Processing Record 42 of Set 3 | nanortalik
# Processing Record 43 of Set 3 | tabas
# Processing Record 44 of Set 3 | maputo
# Processing Record 45 of Set 3 | pacific grove
# Processing Record 46 of Set 3 | padang
# Processing Record 47 of Set 3 | lebu
# Processing Record 48 of Set 3 | clyde river
# Processing Record 49 of Set 3 | saldanha
# Processing Record 50 of Set 3 | knysna
# Processing Record 1 of Set 4 | tasiilaq
# Processing Record 2 of Set 4 | hithadhoo
# Processing Record 3 of Set 4 | kribi
# Processing Record 4 of Set 4 | jamestown
# Processing Record 5 of Set 4 | constitucion
# Processing Record 6 of Set 4 | dodge city
# Processing Record 7 of Set 4 | mayya
# Processing Record 8 of Set 4 | sidi ali
# Processing Record 9 of Set 4 | homer
# Processing Record 10 of Set 4 | nantucket
# Processing Record 11 of Set 4 | yarmouth
# Processing Record 12 of Set 4 | ruteng
# Processing Record 13 of Set 4 | ponta do sol
# Processing Record 14 of Set 4 | westport
# Processing Record 15 of Set 4 | zychlin
# Processing Record 16 of Set 4 | korla
# Processing Record 17 of Set 4 | alibag
# Processing Record 18 of Set 4 | andenes
# Processing Record 19 of Set 4 | shudayag
# Processing Record 20 of Set 4 | esna
# Processing Record 21 of Set 4 | kapaa
# Processing Record 22 of Set 4 | saint anthony
# Processing Record 23 of Set 4 | tiksi
# Processing Record 24 of Set 4 | kodiak
# Processing Record 25 of Set 4 | klaksvik
# Processing Record 26 of Set 4 | gushikawa
# Processing Record 27 of Set 4 | osakarovka
# Processing Record 28 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 4 | beboto
# Processing Record 30 of Set 4 | sampit
# Processing Record 31 of Set 4 | georgetown
# Processing Record 32 of Set 4 | khormuj
# City not found. Skipping...
# Processing Record 33 of Set 4 | buraydah
# Processing Record 34 of Set 4 | huarmey
# Processing Record 35 of Set 4 | caravelas
# Processing Record 36 of Set 4 | aurillac
# Processing Record 37 of Set 4 | stawell
# Processing Record 38 of Set 4 | phalaborwa
# Processing Record 39 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 40 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 41 of Set 4 | east london
# Processing Record 42 of Set 4 | leningradskiy
# Processing Record 43 of Set 4 | norfolk
# Processing Record 44 of Set 4 | loralai
# Processing Record 45 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 46 of Set 4 | batang berjuntai
# Processing Record 47 of Set 4 | dehloran
# Processing Record 48 of Set 4 | yellowknife
# Processing Record 49 of Set 4 | san quintin
# Processing Record 50 of Set 4 | christchurch
# Processing Record 1 of Set 5 | fabiansebestyen
# Processing Record 2 of Set 5 | berlevag
# Processing Record 3 of Set 5 | srednekolymsk
# Processing Record 4 of Set 5 | linden
# Processing Record 5 of Set 5 | manono
# Processing Record 6 of Set 5 | lazaro cardenas
# Processing Record 7 of Set 5 | muswellbrook
# Processing Record 8 of Set 5 | tiznit
# Processing Record 9 of Set 5 | puerto ayora
# Processing Record 10 of Set 5 | deputatskiy
# Processing Record 11 of Set 5 | kavaratti
# Processing Record 12 of Set 5 | merauke
# Processing Record 13 of Set 5 | port hardy
# Processing Record 14 of Set 5 | pestravka
# Processing Record 15 of Set 5 | spearfish
# Processing Record 16 of Set 5 | sao gabriel da cachoeira
# Processing Record 17 of Set 5 | carnarvon
# Processing Record 18 of Set 5 | plattsburgh
# Processing Record 19 of Set 5 | ilulissat
# Processing Record 20 of Set 5 | reinosa
# Processing Record 21 of Set 5 | vero beach
# Processing Record 22 of Set 5 | aksu
# Processing Record 23 of Set 5 | port macquarie
# Processing Record 24 of Set 5 | nabire
# Processing Record 25 of Set 5 | victoria
# Processing Record 26 of Set 5 | vardo
# Processing Record 27 of Set 5 | northview
# Processing Record 28 of Set 5 | xixiang
# Processing Record 29 of Set 5 | hirtshals
# Processing Record 30 of Set 5 | sola
# Processing Record 31 of Set 5 | castro
# Processing Record 32 of Set 5 | kruisfontein
# Processing Record 33 of Set 5 | batagay-alyta
# Processing Record 34 of Set 5 | kano
# Processing Record 35 of Set 5 | ardesen
# Processing Record 36 of Set 5 | nemuro
# Processing Record 37 of Set 5 | jamsa
# Processing Record 38 of Set 5 | pizhanka
# Processing Record 39 of Set 5 | reconquista
# Processing Record 40 of Set 5 | solnechnyy
# Processing Record 41 of Set 5 | chuy
# Processing Record 42 of Set 5 | shahrud
# Processing Record 43 of Set 5 | laguna
# Processing Record 44 of Set 5 | sur
# Processing Record 45 of Set 5 | barreiras
# Processing Record 46 of Set 5 | longyearbyen
# Processing Record 47 of Set 5 | shahjahanpur
# Processing Record 48 of Set 5 | kilis
# Processing Record 49 of Set 5 | payo
# Processing Record 50 of Set 5 | kyren
# Processing Record 1 of Set 6 | palafrugell
# Processing Record 2 of Set 6 | shirokiy
# Processing Record 3 of Set 6 | nouadhibou
# Processing Record 4 of Set 6 | bar harbor
# Processing Record 5 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 6 | juegang
# Processing Record 8 of Set 6 | chara
# Processing Record 9 of Set 6 | mabaruma
# Processing Record 10 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 6 | soe
# Processing Record 12 of Set 6 | san patricio
# Processing Record 13 of Set 6 | roald
# Processing Record 14 of Set 6 | maceio
# Processing Record 15 of Set 6 | asheboro
# Processing Record 16 of Set 6 | masuda
# Processing Record 17 of Set 6 | wanning
# Processing Record 18 of Set 6 | lincoln
# Processing Record 19 of Set 6 | simpsonville
# Processing Record 20 of Set 6 | san pedro
# Processing Record 21 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 22 of Set 6 | sangar
# Processing Record 23 of Set 6 | high level
# Processing Record 24 of Set 6 | ayan
# Processing Record 25 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 6 | lavrentiya
# Processing Record 27 of Set 6 | emerald
# Processing Record 28 of Set 6 | biskamzha
# Processing Record 29 of Set 6 | meulaboh
# Processing Record 30 of Set 6 | saint-raymond
# Processing Record 31 of Set 6 | diego de almagro
# Processing Record 32 of Set 6 | pizarro
# Processing Record 33 of Set 6 | quatre cocos
# Processing Record 34 of Set 6 | severo-kurilsk
# Processing Record 35 of Set 6 | aasiaat
# Processing Record 36 of Set 6 | tuatapere
# Processing Record 37 of Set 6 | eunice
# Processing Record 38 of Set 6 | new norfolk
# Processing Record 39 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 6 | necochea
# Processing Record 41 of Set 6 | biak
# Processing Record 42 of Set 6 | kamaishi
# Processing Record 43 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 6 | hailar
# Processing Record 46 of Set 6 | bend
# Processing Record 47 of Set 6 | susanville
# Processing Record 48 of Set 6 | verkhnyaya inta
# Processing Record 49 of Set 6 | lompoc
# Processing Record 50 of Set 6 | el dorado
# Processing Record 1 of Set 7 | broken hill
# Processing Record 2 of Set 7 | le port
# Processing Record 3 of Set 7 | faanui
# Processing Record 4 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 7 | dongkan
# Processing Record 6 of Set 7 | coracao de jesus
# Processing Record 7 of Set 7 | brae
# Processing Record 8 of Set 7 | rotifunk
# Processing Record 9 of Set 7 | mandiana
# Processing Record 10 of Set 7 | monteagudo
# Processing Record 11 of Set 7 | prince rupert
# Processing Record 12 of Set 7 | norman wells
# Processing Record 13 of Set 7 | ojinaga
# Processing Record 14 of Set 7 | morki
# Processing Record 15 of Set 7 | ahipara
# Processing Record 16 of Set 7 | palmer
# Processing Record 17 of Set 7 | kaniama
# Processing Record 18 of Set 7 | thohoyandou
# Processing Record 19 of Set 7 | coihaique
# Processing Record 20 of Set 7 | angola
# Processing Record 21 of Set 7 | tabialan
# City not found. Skipping...
# Processing Record 22 of Set 7 | muros
# Processing Record 23 of Set 7 | flinders
# Processing Record 24 of Set 7 | bhawanipatna
# Processing Record 25 of Set 7 | beni suef
# Processing Record 26 of Set 7 | iqaluit
# Processing Record 27 of Set 7 | muriti
# Processing Record 28 of Set 7 | dalbandin
# Processing Record 29 of Set 7 | gazanjyk
# Processing Record 30 of Set 7 | zaysan
# Processing Record 31 of Set 7 | san bartolome
# Processing Record 32 of Set 7 | touros
# Processing Record 33 of Set 7 | oranjemund
# Processing Record 34 of Set 7 | scarborough
# Processing Record 35 of Set 7 | feira
# Processing Record 36 of Set 7 | portland
# Processing Record 37 of Set 7 | tessalit
# Processing Record 38 of Set 7 | marevo
# Processing Record 39 of Set 7 | darhan
# Processing Record 40 of Set 7 | tura
# Processing Record 41 of Set 7 | xihe
# Processing Record 42 of Set 7 | lujan
# Processing Record 43 of Set 7 | chifeng
# Processing Record 44 of Set 7 | oblivskaya
# Processing Record 45 of Set 7 | bambanglipuro
# Processing Record 46 of Set 7 | cherskiy
# Processing Record 47 of Set 7 | marquette
# Processing Record 48 of Set 7 | churapcha
# Processing Record 49 of Set 7 | codrington
# Processing Record 50 of Set 7 | abha
# Processing Record 1 of Set 8 | chokurdakh
# Processing Record 2 of Set 8 | kerteh
# City not found. Skipping...
# Processing Record 3 of Set 8 | noumea
# Processing Record 4 of Set 8 | anadyr
# Processing Record 5 of Set 8 | matara
# Processing Record 6 of Set 8 | elko
# Processing Record 7 of Set 8 | santa maria
# Processing Record 8 of Set 8 | gogrial
# Processing Record 9 of Set 8 | moose factory
# Processing Record 10 of Set 8 | vestmannaeyjar
# Processing Record 11 of Set 8 | bundaberg
# Processing Record 12 of Set 8 | faya
# Processing Record 13 of Set 8 | bazarnyye mataki
# Processing Record 14 of Set 8 | gravdal
# Processing Record 15 of Set 8 | rio grande
# Processing Record 16 of Set 8 | port blair
# Processing Record 17 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 8 | college
# Processing Record 20 of Set 8 | puerto leguizamo
# Processing Record 21 of Set 8 | kargasok
# Processing Record 22 of Set 8 | belyy yar
# Processing Record 23 of Set 8 | mitsamiouli
# Processing Record 24 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 25 of Set 8 | tlaxiaco
# City not found. Skipping...
# Processing Record 26 of Set 8 | alofi
# Processing Record 27 of Set 8 | perth
# Processing Record 28 of Set 8 | torbay
# Processing Record 29 of Set 8 | unecha
# Processing Record 30 of Set 8 | beringovskiy
# Processing Record 31 of Set 8 | luderitz
# Processing Record 32 of Set 8 | kavieng
# Processing Record 33 of Set 8 | labuhan
# Processing Record 34 of Set 8 | madang
# Processing Record 35 of Set 8 | belaya gora
# Processing Record 36 of Set 8 | russell
# Processing Record 37 of Set 8 | tateyama
# Processing Record 38 of Set 8 | garowe
# Processing Record 39 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 8 | bogande
# Processing Record 41 of Set 8 | constantine
# Processing Record 42 of Set 8 | alyangula
# Processing Record 43 of Set 8 | kilindoni
# Processing Record 44 of Set 8 | ucluelet
# Processing Record 45 of Set 8 | bandarban
# Processing Record 46 of Set 8 | lata
# Processing Record 47 of Set 8 | toora-khem
# Processing Record 48 of Set 8 | sukhobezvodnoye
# Processing Record 49 of Set 8 | vostok
# Processing Record 50 of Set 8 | pyapon
# Processing Record 1 of Set 9 | majene
# Processing Record 2 of Set 9 | mecca
# Processing Record 3 of Set 9 | kindersley
# Processing Record 4 of Set 9 | alamosa
# Processing Record 5 of Set 9 | atasu
# Processing Record 6 of Set 9 | provideniya
# Processing Record 7 of Set 9 | aklavik
# Processing Record 8 of Set 9 | altay
# Processing Record 9 of Set 9 | port hawkesbury
# Processing Record 10 of Set 9 | puerto lempira
# Processing Record 11 of Set 9 | souillac
# Processing Record 12 of Set 9 | jiwani
# Processing Record 13 of Set 9 | la ronge
# Processing Record 14 of Set 9 | asau
# Processing Record 15 of Set 9 | hay river
# Processing Record 16 of Set 9 | malakal
# Processing Record 17 of Set 9 | arlit
# Processing Record 18 of Set 9 | iwanai
# Processing Record 19 of Set 9 | inhambane
# Processing Record 20 of Set 9 | opotiki
# Processing Record 21 of Set 9 | denpasar
# Processing Record 22 of Set 9 | abilene
# Processing Record 23 of Set 9 | malang
# Processing Record 24 of Set 9 | hobyo
# Processing Record 25 of Set 9 | sorland
# Processing Record 26 of Set 9 | chapais
# Processing Record 27 of Set 9 | taoudenni
# Processing Record 28 of Set 9 | hearst
# Processing Record 29 of Set 9 | vao
# Processing Record 30 of Set 9 | tazovskiy
# Processing Record 31 of Set 9 | leshukonskoye
# Processing Record 32 of Set 9 | rudbar
# Processing Record 33 of Set 9 | san jose
# Processing Record 34 of Set 9 | pundaguitan
# Processing Record 35 of Set 9 | suntar
# Processing Record 36 of Set 9 | puerto suarez
# Processing Record 37 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 38 of Set 9 | north bend
# Processing Record 39 of Set 9 | moa
# Processing Record 40 of Set 9 | ocampo
# Processing Record 41 of Set 9 | inuvik
# Processing Record 42 of Set 9 | salalah
# Processing Record 43 of Set 9 | maniitsoq
# Processing Record 44 of Set 9 | atambua
# Processing Record 45 of Set 9 | ixtapa
# Processing Record 46 of Set 9 | barahona
# Processing Record 47 of Set 9 | sarab
# Processing Record 48 of Set 9 | montecristo
# Processing Record 49 of Set 9 | los llanos de aridane
# Processing Record 50 of Set 9 | zheleznodorozhnyy
# Processing Record 1 of Set 10 | yuzhnyy
# Processing Record 2 of Set 10 | port moresby
# Processing Record 3 of Set 10 | batsfjord
# Processing Record 4 of Set 10 | baghdad
# Processing Record 5 of Set 10 | kualakapuas
# Processing Record 6 of Set 10 | fortuna
# Processing Record 7 of Set 10 | sitka
# Processing Record 8 of Set 10 | ulkan
# Processing Record 9 of Set 10 | pangnirtung
# Processing Record 10 of Set 10 | puerto escondido
# Processing Record 11 of Set 10 | villarrica
# Processing Record 12 of Set 10 | humberto de campos
# Processing Record 13 of Set 10 | vengerovo
# Processing Record 14 of Set 10 | sao jose da coroa grande
# Processing Record 15 of Set 10 | yumen
# Processing Record 16 of Set 10 | tucuman
# Processing Record 17 of Set 10 | belmonte
# Processing Record 18 of Set 10 | angoram
# Processing Record 19 of Set 10 | camabatela
# Processing Record 20 of Set 10 | lapeer
# Processing Record 21 of Set 10 | maragogi
# Processing Record 22 of Set 10 | tete
# Processing Record 23 of Set 10 | vershino-darasunskiy
# Processing Record 24 of Set 10 | bakau
# Processing Record 25 of Set 10 | orizona
# Processing Record 26 of Set 10 | kendari
# Processing Record 27 of Set 10 | raudeberg
# Processing Record 28 of Set 10 | tual
# Processing Record 29 of Set 10 | goderich
# Processing Record 30 of Set 10 | ciudad real
# Processing Record 31 of Set 10 | tamandare
# Processing Record 32 of Set 10 | sambava
# Processing Record 33 of Set 10 | esmeraldas
# Processing Record 34 of Set 10 | kungurtug
# Processing Record 35 of Set 10 | lovozero
# Processing Record 36 of Set 10 | qaqortoq
# Processing Record 37 of Set 10 | marienburg
# Processing Record 38 of Set 10 | bronnoysund
# Processing Record 39 of Set 10 | hirara
# Processing Record 40 of Set 10 | cayenne
# Processing Record 41 of Set 10 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 42 of Set 10 | yazman
# Processing Record 43 of Set 10 | mandali
# Processing Record 44 of Set 10 | sept-iles
# Processing Record 45 of Set 10 | kaohsiung
# Processing Record 46 of Set 10 | santa cruz
# Processing Record 47 of Set 10 | lao cai
# Processing Record 48 of Set 10 | annonay
# Processing Record 49 of Set 10 | alice springs
# Processing Record 50 of Set 10 | wajima
# Processing Record 1 of Set 11 | kaeo
# Processing Record 2 of Set 11 | mahon
# Processing Record 3 of Set 11 | baker city
# Processing Record 4 of Set 11 | carutapera
# Processing Record 5 of Set 11 | abeche
# Processing Record 6 of Set 11 | ust-ishim
# Processing Record 7 of Set 11 | lhokseumawe
# Processing Record 8 of Set 11 | bolivar
# Processing Record 9 of Set 11 | tonantins
# Processing Record 10 of Set 11 | bama
# Processing Record 11 of Set 11 | bitburg
# Processing Record 12 of Set 11 | tigil
# Processing Record 13 of Set 11 | mount gambier
# Processing Record 14 of Set 11 | bridlington
# Processing Record 15 of Set 11 | barguzin
# Processing Record 16 of Set 11 | bathurst
# Processing Record 17 of Set 11 | tilichiki
# Processing Record 18 of Set 11 | sobolevo
# Processing Record 19 of Set 11 | takoradi
# Processing Record 20 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 11 | amalapuram
# Processing Record 22 of Set 11 | mucurici
# Processing Record 23 of Set 11 | kimbe
# Processing Record 24 of Set 11 | lufilufi
# Processing Record 25 of Set 11 | novosergiyevka
# Processing Record 26 of Set 11 | karimnagar
# Processing Record 27 of Set 11 | alekseyevsk
# Processing Record 28 of Set 11 | zamora
# Processing Record 29 of Set 11 | puerto baquerizo moreno
# Processing Record 30 of Set 11 | ellisras
# Processing Record 31 of Set 11 | west wendover
# Processing Record 32 of Set 11 | nova era
# Processing Record 33 of Set 11 | billings
# Processing Record 34 of Set 11 | vizovice
# Processing Record 35 of Set 11 | banff
# Processing Record 36 of Set 11 | ajdabiya
# Processing Record 37 of Set 11 | erzin
# Processing Record 38 of Set 11 | sao joao da barra
# Processing Record 39 of Set 11 | adrar
# Processing Record 40 of Set 11 | cururupu
# Processing Record 41 of Set 11 | ancud
# Processing Record 42 of Set 11 | manavalakurichi
# Processing Record 43 of Set 11 | road town
# Processing Record 44 of Set 11 | jishui
# Processing Record 45 of Set 11 | kahului
# Processing Record 46 of Set 11 | colesberg
# Processing Record 47 of Set 11 | cap malheureux
# Processing Record 48 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 49 of Set 11 | plavsk
# Processing Record 50 of Set 11 | la romana
# Processing Record 1 of Set 12 | imbituba
# Processing Record 2 of Set 12 | grand gaube
# Processing Record 3 of Set 12 | honningsvag
# Processing Record 4 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 5 of Set 12 | terme
# Processing Record 6 of Set 12 | bosansko grahovo
# Processing Record 7 of Set 12 | qui nhon
# Processing Record 8 of Set 12 | mahibadhoo
# Processing Record 9 of Set 12 | gerlafingen
# Processing Record 10 of Set 12 | marzuq
# Processing Record 11 of Set 12 | vung tau
# Processing Record 12 of Set 12 | pisco
# Processing Record 13 of Set 12 | yatou
# Processing Record 14 of Set 12 | nanaimo
# Processing Record 15 of Set 12 | watford
# Processing Record 16 of Set 12 | neftcala
# Processing Record 17 of Set 12 | lagos
# Processing Record 18 of Set 12 | karakulino
# Processing Record 19 of Set 12 | cedar city
# Processing Record 20 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 12 | kendal
# Processing Record 22 of Set 12 | el tigre
# Processing Record 23 of Set 12 | cabedelo
# Processing Record 24 of Set 12 | maniwaki
# Processing Record 25 of Set 12 | jiazi
# Processing Record 26 of Set 12 | blagoyevo
# Processing Record 27 of Set 12 | pimenta bueno
# Processing Record 28 of Set 12 | princeton
# Processing Record 29 of Set 12 | latung
# Processing Record 30 of Set 12 | ballina
# Processing Record 31 of Set 12 | kailua
# Processing Record 32 of Set 12 | upington
# Processing Record 33 of Set 12 | calabozo
# Processing Record 34 of Set 12 | voh
# Processing Record 35 of Set 12 | banda aceh
# Processing Record 36 of Set 12 | vila velha
# Processing Record 37 of Set 12 | maningrida
# Processing Record 38 of Set 12 | nyurba
# Processing Record 39 of Set 12 | namibe
# Processing Record 40 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 41 of Set 12 | galle
# Processing Record 42 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 43 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 12 | shediac
# Processing Record 45 of Set 12 | manggar
# Processing Record 46 of Set 12 | belo jardim
# Processing Record 47 of Set 12 | unguia
# Processing Record 48 of Set 12 | laives
# Processing Record 49 of Set 12 | aldan
# Processing Record 50 of Set 12 | ishigaki
# Processing Record 1 of Set 13 | muli
# Processing Record 2 of Set 13 | mirabad
# Processing Record 3 of Set 13 | sinnamary
# Processing Record 4 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 13 | kloulklubed
# Processing Record 6 of Set 13 | vila franca do campo
# Processing Record 7 of Set 13 | aswan
# Processing Record 8 of Set 13 | muyezerskiy
# Processing Record 9 of Set 13 | comodoro rivadavia
# Processing Record 10 of Set 13 | malumfashi
# Processing Record 11 of Set 13 | kasempa
# Processing Record 12 of Set 13 | togur
# Processing Record 13 of Set 13 | glendive
# Processing Record 14 of Set 13 | morant bay
# Processing Record 15 of Set 13 | okha
# Processing Record 16 of Set 13 | qandala
# Processing Record 17 of Set 13 | manokwari
# Processing Record 18 of Set 13 | harper
# Processing Record 19 of Set 13 | ewa beach
# Processing Record 20 of Set 13 | kovdor
# Processing Record 21 of Set 13 | marrakesh
# Processing Record 22 of Set 13 | innisfail
# Processing Record 23 of Set 13 | gander
# Processing Record 24 of Set 13 | mogadishu
# Processing Record 25 of Set 13 | gamba
# Processing Record 26 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 27 of Set 13 | cabrero
# Processing Record 28 of Set 13 | kuala krai
# City not found. Skipping...
# Processing Record 29 of Set 13 | saurimo
# Processing Record 30 of Set 13 | viedma
# Processing Record 31 of Set 13 | pocao de pedras
# Processing Record 32 of Set 13 | aripuana
# Processing Record 33 of Set 13 | kidal
# Processing Record 34 of Set 13 | hami
# Processing Record 35 of Set 13 | hvittingfoss
# Processing Record 36 of Set 13 | irbeyskoye
# Processing Record 37 of Set 13 | formosa
# Processing Record 38 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 39 of Set 13 | balud
# Processing Record 40 of Set 13 | coffs harbour
# Processing Record 41 of Set 13 | nipawin
# Processing Record 42 of Set 13 | tanabe
# Processing Record 43 of Set 13 | buala
# Processing Record 44 of Set 13 | soja
# Processing Record 45 of Set 13 | acari
# Processing Record 46 of Set 13 | nuuk
# Processing Record 47 of Set 13 | brawley
# Processing Record 48 of Set 13 | luanda
# Processing Record 49 of Set 13 | manga
# Processing Record 50 of Set 13 | sakakah
# Processing Record 1 of Set 14 | poum
# Processing Record 2 of Set 14 | dicabisagan
# Processing Record 3 of Set 14 | syracuse
# Processing Record 4 of Set 14 | orlovskiy
# Processing Record 5 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 6 of Set 14 | dongsheng
# Processing Record 7 of Set 14 | jaisalmer
# Processing Record 8 of Set 14 | palauig
# Processing Record 9 of Set 14 | tocantinopolis
# City not found. Skipping...
# Processing Record 10 of Set 14 | whitianga
# Processing Record 11 of Set 14 | bela
# Processing Record 12 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 14 | lebanon
# Processing Record 14 of Set 14 | cordoba
# Processing Record 15 of Set 14 | nizhneangarsk
# Processing Record 16 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 17 of Set 14 | aquiraz
# Processing Record 18 of Set 14 | bilibino
# Processing Record 19 of Set 14 | burica
# City not found. Skipping...
# Processing Record 20 of Set 14 | oussouye
# Processing Record 21 of Set 14 | celestun
# Processing Record 22 of Set 14 | haines junction
# Processing Record 23 of Set 14 | coquimbo
# Processing Record 24 of Set 14 | makakilo city
# Processing Record 25 of Set 14 | channel-port aux basques
# Processing Record 26 of Set 14 | miandrivazo
# Processing Record 27 of Set 14 | lobito
# Processing Record 28 of Set 14 | fairbanks
# Processing Record 29 of Set 14 | qasigiannguit
# Processing Record 30 of Set 14 | osypenko
# Processing Record 31 of Set 14 | safwah
# City not found. Skipping...
# Processing Record 32 of Set 14 | nioro
# Processing Record 33 of Set 14 | saint george
# Processing Record 34 of Set 14 | otane
# Processing Record 35 of Set 14 | lorengau
# Processing Record 36 of Set 14 | lae
# Processing Record 37 of Set 14 | sudbury
# Processing Record 38 of Set 14 | malanje
# Processing Record 39 of Set 14 | jamkhandi
# Processing Record 40 of Set 14 | kuala terengganu
# Processing Record 41 of Set 14 | egvekinot
# Processing Record 42 of Set 14 | langsa
# Processing Record 43 of Set 14 | yanam
# Processing Record 44 of Set 14 | brigantine
# Processing Record 45 of Set 14 | kutum
# Processing Record 46 of Set 14 | shagonar
# Processing Record 47 of Set 14 | bereda
# Processing Record 48 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 49 of Set 14 | jujuy
# City not found. Skipping...
# Processing Record 50 of Set 14 | itacurubi de la cordillera
# Processing Record 1 of Set 15 | nurobod
# Processing Record 2 of Set 15 | lodwar
# Processing Record 3 of Set 15 | bahia honda
# Processing Record 4 of Set 15 | elizabeth city
# Processing Record 5 of Set 15 | ranong
# Processing Record 6 of Set 15 | tondano
# Processing Record 7 of Set 15 | potrerillos
# Processing Record 8 of Set 15 | allapalli
# Processing Record 9 of Set 15 | izhma
# Processing Record 10 of Set 15 | kagay
# Processing Record 11 of Set 15 | bonavista
# Processing Record 12 of Set 15 | mehamn
# Processing Record 13 of Set 15 | thale
# Processing Record 14 of Set 15 | dire dawa
# Processing Record 15 of Set 15 | benguela
# Processing Record 16 of Set 15 | gimli
# Processing Record 17 of Set 15 | ouallam
# Processing Record 18 of Set 15 | ola
# Processing Record 19 of Set 15 | sibanicu
# Processing Record 20 of Set 15 | hambantota
# Processing Record 21 of Set 15 | haapiti
# Processing Record 22 of Set 15 | oriximina
# Processing Record 23 of Set 15 | iquitos
# Processing Record 24 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 15 | bouca
# Processing Record 26 of Set 15 | ife
# Processing Record 27 of Set 15 | laredo
# Processing Record 28 of Set 15 | raul soares
# Processing Record 29 of Set 15 | soyo
# Processing Record 30 of Set 15 | olafsvik
# Processing Record 31 of Set 15 | pampa
# Processing Record 32 of Set 15 | talcahuano
# Processing Record 33 of Set 15 | ubajara
# Processing Record 34 of Set 15 | okhotsk
# Processing Record 35 of Set 15 | guangyuan
# Processing Record 36 of Set 15 | lujiang
# Processing Record 37 of Set 15 | moron
# Processing Record 38 of Set 15 | moranbah
# Processing Record 39 of Set 15 | lohr
# Processing Record 40 of Set 15 | mildura
# Processing Record 41 of Set 15 | mucurapo
# Processing Record 42 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 15 | poronaysk
# Processing Record 44 of Set 15 | blackmans
# City not found. Skipping...
# Processing Record 45 of Set 15 | draganesti
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Srandakan      ID  -7.9386  110.2506     75.72        62         100
# 1       Palizada      MX  18.2500  -92.0833     69.15        94           5
# 2        Miranda      CO   3.2499  -76.2281     71.73        96         100
# 3    Verkhoyansk      RU  67.5447  133.3850    -16.55        90          78
# 4           Bose      IT  45.4612    8.0137     42.24        51          12
# 5          Avera      US  33.1940  -82.5271     55.27        65           0
# 6          Aksha      RU  50.2814  113.2867     -0.71        68         100
# 7      Bathsheba      BB  13.2167  -59.5167     77.61        53          20
# 8         Akdepe      TM  42.0551   59.3788     33.80        65          66
# 9  Cockburn Town      TC  21.4612  -71.1419     77.43        84           3
#
#    Wind Speed Current Description
# 0        1.03     overcast clouds
# 1        3.98           clear sky
# 2        1.36     overcast clouds
# 3        1.16       broken clouds
# 4        4.27          few clouds
# 5        6.49           clear sky
# 6        5.46     overcast clouds
# 7       21.85          few clouds
# 8        5.93       broken clouds
# 9       22.93           clear sky

# %%
# Create the output file (CSV).
output_data_file = os.path.join("Weather_Database" , "WeatherPy_Database.csv")

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
